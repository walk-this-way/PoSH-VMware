# %%
import json
import pandas as pd

# %%
data = json.load(open('./vSphere_14-06-2024-02-26.json'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 data = json.load(open('./vSphere_14-06-2024-02-26.json'))
# ----> 2 data.info()
#
# AttributeError: 'dict' object has no attribute 'info'
